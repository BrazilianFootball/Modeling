# %%
import pandas as pd

# %%
cols = [
    "name",
    "50%",
    "mean",
    "std",
    "2.5%",
    "97.5%",
    "team",
    "total_minutes",
    "total_games",
    "total_wins",
    "total_draws",
    "weighted_score",
]

# %%
file_name = "../real_data/player_level_results/players_summary_2025_poisson_7.csv"
df = pd.read_csv(file_name)
df.sort_values(by="50%", ascending=False).head(21)[cols]
# Out:
#                                                   name       50%      mean  \
# 0                                                  NaN  0.422409  0.421739
# 3              1ROSSI Agustin Daniel Rossi T(g)P815100  0.048874  0.048506
# 5               4Leo Pereira Leonardo Pereira TP310373  0.044572  0.044566
# 363  10De Arrascaeta Giorgian Daniel de A ... TP521990  0.034693  0.034591
# 4              3Léo Ortiz Leonardo Rech Ortiz TP422469  0.030027  0.030543
# 7              7Luiz Luiz de Araujo Guima ... TP424455  0.029691  0.030077
# 168       19Kaio Jorge Kaio Jorge Pinto Ramos TP541499  0.028443  0.027151
# 383          25Villalba Lucas Hernan Villalba RP837958  0.026785  0.026270
# 66    21Weverton Weverton Pereira da Silva T(g)P169050  0.026598  0.026827
# 167  15Fabrício B ... Fabricio Bruno Soare ... TP38...  0.025130  0.024428
# 182          16Lucas Silva Lucas Silva Borges RP320111  0.024402  0.024283
# ...

# %%
df.sort_values(by="50%", ascending=True).head(21)[cols]
# Out:
#                                                   name       50%      mean  \
# 2                                                  NaN -2.285270 -2.497634
# 111         14RIVERA Christian Hernando R ... TP896161 -0.028374 -0.028173
# 110     10Lucas Lima Lucas Rafael Araujo Lima TP331937 -0.027108 -0.026855
# 126  33Matheus Al ... Matheus Alexandre An ... RP51... -0.024423 -0.024197
# 283          16Jadson Jadson Alves dos Santos TP302192 -0.023841 -0.022935
# 290     21Gabriel Gabriel Vasconcelos  ... T(g)P315345 -0.021853 -0.022313
# 558      15R. Thyere Rafael Thyere de Alb ... RP313474 -0.020299 -0.021541
# 559    17Matheusinho Matheus Leonardo Sal ... TP398805 -0.019284 -0.018570
# 560          21Lucas Lucas Kal Schenfeld  ... TP337242 -0.019219 -0.019032
# 561    36Luan Candido Luan Candido de Almeida RP540157 -0.018531 -0.017405
# 288           44Luiz Luiz Gustavo da Silv ... TP539820 -0.017252 -0.017145
# ...

# %%
file_name = "../real_data/player_level_results/players_summary_2020-2025_poisson_7.csv"
df = pd.read_csv(file_name)
df.sort_values(by="50%", ascending=False).head(21)[cols]
# Out:
#                                                    name       50%      mean  \
# 0                                                   NaN  0.323372  0.323355
# 413     1Weverton Weverton Pereira da Silva T(g)P169050  0.131210  0.130785
# 11    14de Arrasca ... Giorgian Daniel de A ... TP52...  0.093575  0.093843
# 113   14Fabricio B ... Fabricio Bruno Soare ... TP38...  0.083366  0.082918
# 414   15GUSTAVO GOMEZ Gustavo Raul Gomez P ... TP633571  0.082612  0.083038
# 1030            26Murilo Murilo Cerqueira Paim TP392224  0.081771  0.081470
# 921   22Joaquin Pi ... Joaquin Piquerez Moreira RP72...  0.080646  0.080371
# 320   23Raphael Veiga Raphael Cavalcante Veiga TP308405  0.076939  0.076761
# 312     2Marcos Rocha Marcos Luis Rocha Aquino TP176390  0.076119  0.075611
# 5                4Leo Pereira Leonardo Pereira TP310373  0.065976  0.065354
# 314              8Ze Rafael Jose Rafael Vivian TP330886  0.064018  0.064268
# ...

# %%
df.sort_values(by="50%", ascending=True).head(21)[cols]
# Out:
#                                                    name       50%      mean  \
# 2                                                   NaN -4.787425 -5.228681
# 1243      1Gabriel Gabriel Vasconcelos  ... R(g)P315345 -0.053075 -0.053002
# 426           71Jadson Jadson Alves dos Santos RP302192 -0.050361 -0.050355
# 70       20Lucas Lima Lucas Rafael Araujo Lima TP331937 -0.043818 -0.044476
# 1048          80PITTA Isidro Miguel Pitta  ... RP750089 -0.036918 -0.036602
# 34             2Kevin Kevin Peterson dos S ... TP502001 -0.036840 -0.037107
# 281          23Tadeu Tadeu Antonio Ferreira T(g)P308316 -0.035875 -0.036004
# 1063    40Matheusinho Matheus Leonardo Sal ... RP398805 -0.034545 -0.034897
# 137               3Eder Eder Ferreira Graminho TP318115 -0.031677 -0.032880
# 1079        27Matheus Matheus Alexandre An ... RP517052 -0.031149 -0.031977
# 646   5Gabriel  B ... Gabriel Baralhas dos ... TP435315 -0.031071 -0.031168
# ...

# %%
file_name = "../real_data/player_level_results/players_summary_2013-2025_poisson_7.csv"
df = pd.read_csv(file_name)
df.sort_values(by="50%", ascending=False).head(21)[cols]
# Out:
#                                                    name       50%      mean  \
# 0                                                   NaN  0.383615  0.383835
# 42       12Weverton Weverton Pereira da ... T(g)P169050  0.188890  0.187893
# 202   17Everton Ri ... Everton Augusto de B ... TP17...  0.139901  0.140382
# 751              7Dudu Eduardo Pereira Rodr... TP291738  0.123556  0.122858
# 320           2Marcos Marcos Luis Rocha Aquino RP176390  0.122522  0.122166
# 1934  15GUSTAVO GOMEZ GUSTAVO RAUL GOMEZ P ... TP633571  0.112485  0.111500
# 1128  10de Arrasca ... Giorgian Daniel de A... TP521990  0.111833  0.110237
# 312          17Willian Willian Souza Arao d... RP293420  0.111624  0.112065
# 281          14Gustavo Gustavo Henrique Vernes RP186450  0.105261  0.105203
# 738               6Rene Rene Rodrigues Martins TP346636  0.099020  0.098396
# 1489        20Raphael Raphael Cavalcante Veiga RP308405  0.098923  0.098359
# ...

# %%
df.sort_values(by="50%", ascending=True).head(21)[cols]
# Out:
#                                                    name       50%      mean  \
# 2                                                   NaN -6.121535 -6.755956
# 1087           7Jadson Jadson Alves dos Santos TP302192 -0.076139 -0.076966
# 88      2Nino Paraíba Severino do Ramo Cle ... TP183977 -0.062960 -0.062982
# 130          5Edicarlos Elicarlos Souza Santos TP169835 -0.056445 -0.055340
# 2806      1Gabriel Gabriel Vasconcelos  ... R(g)P315345 -0.051281 -0.051572
# 655        12Vladimir Vladimir Orlando Car ... RP180622 -0.049463 -0.049881
# 2023         23Tadeu Tadeu Antonio Ferreira T(g)P308316 -0.045543 -0.046016
# 503      4Ebert Will ... Ebert Willian Amancio TP144059 -0.045474 -0.045409
# 365         28Adilson Adilson dos Anjos Ol ... RP337261 -0.044282 -0.044377
# 1407         21Matheus Matheus Leonardo Sal... RP398805 -0.044166 -0.043732
# 135          10Rogerio Jose Rogerio de Oliv... TP291780 -0.040178 -0.041252
# ...
